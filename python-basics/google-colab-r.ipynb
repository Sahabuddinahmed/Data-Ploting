# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahabuddinahmed/Data-Ploting/blob/master/python-basics/google-colab-r.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Colab R
#
# - Google is now supporting a Colab notebook with the R kernel
# - We can run R codes directly on Colab
# - R Colab Notebook Link: [R Google Colab](https://colab.fan/r)
#     - Colab with R kernel
#     - With base-R installed
#     - Run R codes immediately
#     - No need to setup
#     - Save a copy in your Drive

# %% [markdown]
# ## Demonstration
#
# This notebook uses the R kernel.

# %% [markdown]
# # New Section
